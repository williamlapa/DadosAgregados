# %% [markdown]
# # Trabalho Final - Ciência de Dados - Enap / 2020
# ## Aluno: William Lapa Santos Filho

# %% [markdown]
# ### Apresentação do Dataset:
#
# #### Tratam-se de base dados PÚBLICA coletada obtidas dos valores agregados por município das Declarações de Imposto de Renda da Pessoa Física (DIRPF) hospedadas no portal Grandes Números DIRPF elaborado pelo CETAD (Centro de Estudos Tributários e Aduaneiros) vinculado à Receita Federal do Brasil. Foram extraídas as informações das DIRPFs entregues por município de jurisdição dos contribuintes dos anos-calendários de 2015 a 2018.
# #### Fonte: https://receita.economia.gov.br/dados/receitadata/estudos-e-tributarios-e-aduaneiros/estudos-e-estatisticas/11-08-2014-grandes-numeros-dirpf/grandes-numeros-dirpf-capa
#
# #### Também utilizaremos a base de população, PIB e PIB per Capita por município obtida junto ao IBGE do site https://sidra.ibge.gov.br/

# %% [markdown]
# ### Motivação Pessoal:
#
# #### Tratam-se de informações relevantes para análise da evolução de rendimentos e bens declarados para a administração tributária federal, cujo escopo faz parte da minha atividade profissional.

# %% [markdown]
# ## Investigação:
#
# ### Hipóteses a serem testadas:
#
# ### 1) Os municípios com maior renda per capita (mais ricos) apresentam maiores rendimentos declarados em 2018?
#
# ### 2) Os municípios mais ricos apresentam maior rendimento declarado por qtde de declarantes em 2018?
#
# ### 3) As deduções com instrução (educação) são relacionadas com os municípios mais ricos (maiores Pib per Capita) em 2018?
#
# ### 4) Houve evolução de 215 a 2018 nos rendimentos totais declarados no modelo completo em relação aos municípios com menor Pib Per Capita?

# %% [markdown]
# ## Importando as principais bibliotecas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Codigo para rodar no Colab caso necvessário.
#from google.colab import drive
#drive.mount('/content/drive/')

# %% [markdown]
# # Análise Informações DIRPF Agregadas

# %% [markdown]
# ### Dataset - Importando a base de dados e realizando tratamento iniciais

# %%
# Importando a bse de dados da RFB
# fonte: https://receita.economia.gov.br/dados/receitadata/estudos-e-tributarios-e-aduaneiros/estudos-e-estatisticas/11-08-2014-grandes-numeros-dirpf
# concatenando os arquivos de 2015 a 2018.
# As colunas de Rendimento em diante estão em milhares.

# Importando base de população do site IBGE: https://sidra.ibge.gov.br/

# Para o Google
#decl = pd.read_csv('/content/drive/My Drive/TrabalhoFinal/dirpf2015_2018.csv')
#pop_mun = pd.read_csv('/content/drive/My Drive/TrabalhoFinal/pop_mun.csv')
#pop_uf= pd.read_csv('/content/drive/My Drive/TrabalhoFinal/pop_uf.csv')
#pib_mun= pd.read_csv('/content/drive/My Drive/TrabalhoFinal/pib_munic.csv')


decl = pd.read_csv('dirpf2015_2018.csv')
pop_mun = pd.read_csv('pop_mun.csv')
pop_uf= pd.read_csv('pop_uf.csv')
pib_mun= pd.read_csv('pib_munic.csv')

# %%
print(pop_mun.head())
print(pop_uf.head())
print(pib_mun.head())
# Out:
#                Municipio  Pop Mun 2015  Pop Mun 2016  Pop Mun 2017  \
# 0  ALTA FLORESTA D'OESTE         25578         25506         25437
# 1              ARIQUEMES        104401        105896        107345
# 2                 CABIXI          6355          6289          6224
# 3                 CACOAL         87226         87877         88507
# 4             CEREJEIRAS         17986         17959         17934
#
#    Pop Mun 2018  UF                    chave
# 0         23167  RO  ALTA FLORESTA D'OESTERO
# 1        106168  RO              ARIQUEMESRO
# 2          5438  RO                 CABIXIRO
# 3         84813  RO                 CACOALRO
# 4         16444  RO             CEREJEIRASRO
#    UF  Pop UF 2015  Pop UF 2016  Pop UF 2017  Pop UF 2018
# 0  RO    1768204.0    1787279.0    1805788.0    1757589.0
# 1  AC     803513.0     816687.0     829619.0     869265.0
# 2  AM    3938336.0    4001667.0    4063614.0    4080611.0
# 3  RR     505665.0     514229.0     522636.0     576568.0
# 4  PA    8175113.0    8272724.0    8366628.0    8513497.0
#     Ano  UF  Código do Município            Municipio  PIB x 1000  \
# 0  2015  GO              5200050      ABADIA DE GOIAS  171701.646
# 1  2016  GO              5200050      ABADIA DE GOIAS  165066.914
# 2  2017  GO              5200050      ABADIA DE GOIAS  234041.689
# 3  2018  GO              5200050      ABADIA DE GOIAS  227500.088
# 4  2015  MG              3100104  ABADIA DOS DOURADOS  164480.415
#
#    PIB per capita x 1                       chave
# 0             21748.15      2015ABADIA DE GOIASGO
# 1             20497.57      2016ABADIA DE GOIASGO
# 2             28517.33      2017ABADIA DE GOIASGO
# 3             26505.89      2018ABADIA DE GOIASGO
# 4             23446.96  2015ABADIA DOS DOURADOSMG

# %%
# Primeiro DataFrame contendo informações de população e pib percapita

# Cruzando dados de municípios (fonte: Receita Federal do Brasil) com pib per capita por municípios (fonte: IBGE)
df_pib = decl.merge(pib_mun, left_on='chave', right_on='chave', how='left')
df_pib = df_pib[['Qtde Declarantes', 'Instrução', 'Médicas', 'Bens e Direitos', 'ano',
       'Municipio_x', 'UF_x', 'chave', 'Total Rend',
       'Total Rend por declarante', 'Instrução por declarante',
       'Médicas por declarante', 'Bens e Direitos por declarante', 'Ano'
       , 'Código do Município', 'PIB x 1000',
       'PIB per capita x 1 ']]
df_pib.rename({'UF_x': 'UF', 'Municipio_x': 'Municipio', 'PIB per capita x 1 ':'PIB per capita x 1'},axis=1, inplace=True)
df_pib['chave_pop'] = df_pib['Municipio']+df_pib['UF']

# Cruzando dados de municípios (fonte: Receita Federal do Brasil) com População por municípios e por UF (fonte: IBGE)
df_pib = df_pib.merge(pop_mun, right_on='chave', left_on='chave_pop', how='left')
pd.options.display.float_format = '{:.2f}'.format
df_pib['ano'].astype(int)
del df_pib['UF_y']
del df_pib['chave_y']
del df_pib['chave_x']
del df_pib['Municipio_y']
del df_pib['Ano']
del df_pib['chave_pop']
df_pib.rename({'UF_x': 'UF', 'Municipio_x': 'Municipio'},axis=1, inplace=True)

# Data Frame contendo informações de população e pib percapita
df_pib.head()
# Out:
#    Qtde Declarantes   Instrução     Médicas  Bens e Direitos   ano  \
# 0               884   544087.86  1332363.16      81259268.80  2015
# 1               572   108173.27   258484.35      75752528.36  2015
# 2               926   776157.39  1313360.98     112458949.72  2015
# 3              7246 14736743.17 22390491.54     246027102.31  2015
# 4              2157   883004.50  3011041.26     453803065.76  2015
#
#              Municipio  UF   Total Rend  Total Rend por declarante  \
# 0      ABADIA DE GOIAS  GO  46974653.07                   53138.75
# 1  ABADIA DOS DOURADOS  MG  29753201.79                   52016.09
# 2            ABADIANIA  GO  47339874.13                   51122.97
# 3           ABAETETUBA  PA 402850510.55                   55596.26
# 4               ABAETE  MG 165166853.93                   76572.49
#
#    Instrução por declarante  Médicas por declarante  \
# 0                    615.48                 1507.20
# 1                    189.11                  451.90
# 2                    838.18                 1418.32
# 3                   2033.78                 3090.05
# 4                    409.37                 1395.94
#
#    Bens e Direitos por declarante  Código do Município  PIB x 1000  \
# 0                        91922.25           5200050.00   171701.65
# 1                       132434.49           3100104.00   164480.42
# 2                       121445.95           5200100.00   289003.06
# 3                        33953.51           1500107.00  1192555.06
# 4                       210386.22           3100203.00   339606.98
#
#    PIB per capita x 1  Pop Mun 2015  Pop Mun 2016  Pop Mun 2017  Pop Mun 2018
# 0            21748.15       7895.00       8053.00       8207.00       8583.00
# 1            23446.96       7015.00       7037.00       7059.00       6972.00
# 2            15994.41      18069.00      18427.00      18775.00      19614.00
# 3             7927.59     150431.00     151934.00     153380.00     156292.00
# 4            14429.87      23535.00      23574.00      23611.00      23223.00

# %%
df_pib.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22287 entries, 0 to 22286
# Data columns (total 19 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Qtde Declarantes                22287 non-null  int64
#  1   Instrução                       22287 non-null  float64
#  2   Médicas                         22287 non-null  float64
#  3   Bens e Direitos                 22287 non-null  float64
#  4   ano                             22287 non-null  int64
#  5   Municipio                       22287 non-null  object
#  6   UF                              22287 non-null  object
#  7   Total Rend                      22287 non-null  float64
#  8   Total Rend por declarante       22286 non-null  float64
#  9   Instrução por declarante        22286 non-null  float64
#  10  Médicas por declarante          22286 non-null  float64
#  11  Bens e Direitos por declarante  22286 non-null  float64
#  12  Código do Município             22050 non-null  float64
#  13  PIB x 1000                      22050 non-null  float64
#  14  PIB per capita x 1              22050 non-null  float64
#  15  Pop Mun 2015                    22042 non-null  float64
#  16  Pop Mun 2016                    22042 non-null  float64
#  17  Pop Mun 2017                    22042 non-null  float64
#  18  Pop Mun 2018                    22042 non-null  float64
# dtypes: float64(15), int64(2), object(2)
# memory usage: 3.4+ MB

# %%
# Testando o dataframe

df_pib[df_pib['Municipio']=='SAO PAULO']
# Out:
#        Qtde Declarantes     Instrução        Médicas  Bens e Direitos   ano  \
# 4992            3031442 2063372428.34  9111872628.36 1652972889333.27  2015
# 10564           3067577 2043329112.58 10117671145.51 1818020254945.48  2016
# 16136           3154445 2039826167.44 11376634226.75 2033502198047.53  2017
# 21707           3248241 1975400672.77 12348333267.49 2149146240806.77  2018
#
#        Municipio  UF      Total Rend  Total Rend por declarante  \
# 4992   SAO PAULO  SP 433389869698.91                  142964.92
# 10564  SAO PAULO  SP 444121319794.46                  144779.19
# 16136  SAO PAULO  SP 482530569985.30                  152968.45
# 21707  SAO PAULO  SP 498025332808.36                  153321.55
#
#        Instrução por declarante  Médicas por declarante  \
# 4992                     680.66                 3005.79
# 10564                    666.11                 3298.26
# 16136                    646.65                 3606.54
# 21707                    608.14                 3801.54
#
#        Bens e Direitos por declarante  Código do Município   PIB x 1000  \
# 4992                        545276.11           3550308.00 653646991.15
# 10564                       592656.76           3550308.00 683066696.84
# 16136                       644646.59           3550308.00 698952189.37
# 21707                       661633.86           3550308.00 714683362.46
#
#        PIB per capita x 1  Pop Mun 2015  Pop Mun 2016  Pop Mun 2017  \
# 4992             54617.02   11967825.00   12038175.00   12106920.00
# 10564            56741.72   11967825.00   12038175.00   12106920.00
# 16136            57731.63   11967825.00   12038175.00   12106920.00
# 21707            58691.90   11967825.00   12038175.00   12106920.00
#
#        Pop Mun 2018
# 4992    12176866.00
# 10564   12176866.00
# 16136   12176866.00
# 21707   12176866.00

# %%
# Testando o dataframe

df_teste = df_pib[(df_pib['UF']=='ES')&(df_pib['Municipio']=='PRESIDENTE KENNEDY')]
df_teste
# Out:
#        Qtde Declarantes  Instrução    Médicas  Bens e Direitos   ano  \
# 3984                819  255335.99 1048890.03     143393297.99  2015
# 9556                927  262487.92 1251219.87     160825108.43  2016
# 15129               977  254074.00 1533290.16     164671016.83  2017
# 20700              1034  334856.66 1989377.84     175675824.58  2018
#
#                 Municipio  UF  Total Rend  Total Rend por declarante  \
# 3984   PRESIDENTE KENNEDY  ES 53239357.33                   65005.32
# 9556   PRESIDENTE KENNEDY  ES 58858902.96                   63493.96
# 15129  PRESIDENTE KENNEDY  ES 62210400.16                   63674.92
# 20700  PRESIDENTE KENNEDY  ES 61697663.59                   59668.92
#
#        Instrução por declarante  Médicas por declarante  \
# 3984                     311.77                 1280.70
# 9556                     283.16                 1349.75
# 15129                    260.06                 1569.39
# 20700                    323.85                 1923.96
#
#        Bens e Direitos por declarante  Código do Município  PIB x 1000  \
# 3984                        175083.39           3204302.00  5803122.99
# 9556                        173489.87           3204302.00  1927270.65
# 15129                       168547.61           3204302.00  3437934.38
# 20700                       169899.25           3204302.00  6699478.16
#
#        PIB per capita x 1  Pop Mun 2015  Pop Mun 2016  Pop Mun 2017  \
# 3984            513142.01      11309.00      11396.00      11742.00
# 9556            169118.17      11309.00      11396.00      11742.00
# 15129           292789.51      11309.00      11396.00      11742.00
# 20700           583171.85      11309.00      11396.00      11742.00
#
#        Pop Mun 2018
# 3984       11488.00
# 9556       11488.00
# 15129      11488.00
# 20700      11488.00

# %%
df_pib.describe()
# Out:
#        Qtde Declarantes     Instrução        Médicas  Bens e Direitos  \
# count          22287.00      22287.00       22287.00         22287.00
# mean            5155.16    3819798.90    13439689.25    1505708958.26
# std            52398.30   38342652.61   191830733.86   28949281482.53
# min                0.00          0.00           0.00             0.00
# 25%              272.00      81510.50      252030.22      16509127.15
# 50%              601.00     217895.55      688009.05      60079926.91
# 75%             1747.00     852764.89     2434256.07     238305918.09
# max          3248241.00 2063372428.34 12348333267.49 2149146240806.77
#
#            ano      Total Rend  Total Rend por declarante  \
# count 22287.00        22287.00                   22286.00
# mean   2016.50    510126893.89                   59687.97
# std       1.12   7476933378.85                   20870.61
# min    2015.00            0.00                   21040.51
# 25%    2015.50     13984588.53                   47553.54
# 50%    2016.00     33714741.82                   56333.74
# 75%    2017.00    110269372.32                   67934.31
# max    2018.00 498025332808.36                  975468.41
#
#        Instrução por declarante  Médicas por declarante  \
# count                  22286.00                22286.00
# mean                     465.15                 1280.67
# std                      319.47                  773.56
# min                        0.00                    0.00
# 25%                      244.16                  808.00
# 50%                      391.03                 1173.87
# 75%                      603.15                 1621.29
# max                     4710.42                46969.95
#
#        Bens e Direitos por declarante  Código do Município   PIB x 1000  \
# count                        22286.00             22050.00     22050.00
# mean                        128479.84           3257100.43   1165608.02
# std                         209446.86            984288.71  11521371.29
# min                            573.08           1100015.00     11501.40
# 25%                          44068.08           2512705.00     76810.80
# 50%                         104887.36           3146552.00    169641.65
# 75%                         179941.89           4119608.00    453034.92
# max                       16014725.14           5300108.00 714683362.46
#
#        PIB per capita x 1  Pop Mun 2015  Pop Mun 2016  Pop Mun 2017  \
# count            22050.00      22042.00      22042.00      22042.00
# mean             21570.12      36803.40      37097.28      37381.78
# std              21443.50     216701.42     218124.31     219517.46
# min               3089.57        818.00        815.00        812.00
# 25%               9214.53       5454.00       5479.00       5499.00
# 50%              16089.48      11507.00      11570.00      11608.00
# 75%              26504.71      24907.00      25052.00      25214.00
# max             583171.85   11967825.00   12038175.00   12106920.00
#
#        Pop Mun 2018
# count      22042.00
# mean       37533.42
# std       221094.89
# min          786.00
# 25%         5454.00
# 50%        11587.00
# 75%        25259.00
# max     12176866.00

# %% [markdown]
# ## Análise exploratória dos dados

# %% [markdown]
# ### Hipótese 1:
#
# #### Existe uma correlação direta positiva em rendimentos totais declarados por contribuinte e o pib per capita de cada município. Iremos testar essa hipótese no gráfico abaixo:

# %%
df_pib[df_pib['ano']==2018].sort_values(
    'PIB per capita x 1',    
    ascending=False    
).head(10
      )
# Out:
#        Qtde Declarantes   Instrução     Médicas  Bens e Direitos   ano  \
# 20700              1034   334856.66  1989377.84     175675824.58  2018
# 18852              5598  1617671.44  8527031.32    1523262909.11  2018
# 21295               617   180574.29   763066.98      46632185.80  2018
# 21528              1172   644794.63  2047275.63     158525620.52  2018
# 20356             30206 34256174.83 87610680.13    8073675180.34  2018
# 21966              4177  1747339.73  6775954.04     538804668.83  2018
# 22207              1078  1339127.39  1650227.68      42859862.88  2018
# 18415              5707  3339300.79  7347868.58     885686526.58  2018
# 19480              9603  4842086.58 17368316.68    2039257867.37  2018
# 21496              3823  5409775.12  6819898.47      32399468.29  2018
#
#                        Municipio  UF    Total Rend  Total Rend por declarante  \
# 20700         PRESIDENTE KENNEDY  ES   61697663.59                   59668.92
# 18852                   ILHABELA  SP  448723029.36                   80157.74
# 21295                   SELVIRIA  MS   45083190.27                   73068.38
# 21528  SAO GONCALO DO RIO ABAIXO  MG   84723722.47                   72289.87
# 20356                   PAULINIA  SP 3052974115.27                  101071.78
# 21966                    TRIUNFO  RS  288607056.24                   69094.34
# 22207           VITORIA DO XINGU  PA   65773658.90                   61014.53
# 18415                    EXTREMA  MG  412964175.91                   72360.99
# 19480                   LOUVEIRA  SP  783182090.90                   81555.98
# 21496     SAO FRANCISCO DO CONDE  BA  203745857.27                   53294.76
#
#        Instrução por declarante  Médicas por declarante  \
# 20700                    323.85                 1923.96
# 18852                    288.97                 1523.23
# 21295                    292.66                 1236.74
# 21528                    550.17                 1746.82
# 20356                   1134.09                 2900.44
# 21966                    418.32                 1622.21
# 22207                   1242.23                 1530.82
# 18415                    585.12                 1287.52
# 19480                    504.23                 1808.63
# 21496                   1415.06                 1783.91
#
#        Bens e Direitos por declarante  Código do Município  PIB x 1000  \
# 20700                       169899.25           3204302.00  6699478.16
# 18852                       272108.42           3520400.00 14401224.60
# 21295                        75578.91           5007802.00  2358953.83
# 21528                       135260.77           3161908.00  3648790.29
# 20356                       267287.13           3536505.00 32690878.46
# 21966                       128993.22           4322004.00  8885017.34
# 22207                        39758.69           1508357.00  4375711.21
# 18415                       155193.01           3125101.00  9523321.08
# 19480                       212356.33           3527306.00 10963451.72
# 21496                         8474.88           2929206.00  8862470.31
#
#        PIB per capita x 1  Pop Mun 2015  Pop Mun 2016  Pop Mun 2017  \
# 20700           583171.85      11309.00      11396.00      11742.00
# 18852           419457.22      32197.00      32782.00      33354.00
# 21295           362080.40       6455.00       6469.00       6482.00
# 21528           337288.81      10588.00      10683.00      10773.00
# 20356           306163.17      97702.00     100128.00     102499.00
# 21966           304208.49      27867.00      28084.00      28289.00
# 22207           291967.12      14407.00      14566.00      14719.00
# 18415           268459.18      33082.00      33729.00      34344.00
# 19480           229610.70      43862.00      44904.00      45922.00
# 21496           225290.31      39329.00      39790.00      40220.00
#
#        Pop Mun 2018
# 20700      11488.00
# 18852      34333.00
# 21295       6515.00
# 21528      10818.00
# 20356     106776.00
# 21966      29207.00
# 22207      14987.00
# 18415      35474.00
# 19480      47748.00
# 21496      39338.00

# %%
fig, ax1 = plt.subplots(1, 1, figsize=(15, 6))
sns.set(style="darkgrid")
ax1 = sns.boxplot(x='ano', y="Total Rend por declarante", data=df_pib)

# %% [markdown]
# ### Hipótese 2:
#
# #### Existe uma correlação direta positiva em Bens e Direitos declarados por contribuinte e o pib per capita de cada município. Iremos testar essa hipótese no gráfico abaixo:

# %%
df_qtde = df_pib.groupby(['ano'], as_index=False).sum()
df_qtde.head()

# %%
fig, ax1 = plt.subplots(1, 1, figsize=(15, 4))
sns.set(style="dark")
ax1 = sns.lineplot(x="ano", y="Qtde Declarantes", data=df_qtde)

# %% [markdown]
# ## Hipótese 3:
#
# #### Há uma relação linear entre crescimento da população e quantidade de declarações enviadas a Receita Federal do Brasil. Iremos testar essa hipótese no gráfico abaixo:

# %%
fig, ax1 = plt.subplots(1, 1, figsize=(15, 4))
sns.set(style="darkgrid")
ax1 = sns.countplot(y="Status", data=dataset)

# %%
fig, ax1 = plt.subplots(1, 1, figsize=(15, 4))
sns.set(style="darkgrid")
ax1 = sns.countplot(y="Tipo de Representação Legal", data=dataset)

# %%
fig, ax1 = plt.subplots(1, 1, figsize=(15, 4))
sns.set(style="whitegrid")
ax1 = sns.countplot(y="Motivo Alteracao Malha", data=dataset)
